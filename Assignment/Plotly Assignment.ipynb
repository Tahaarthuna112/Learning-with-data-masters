# %%
Q1. Load the "titanic" dataset using the load_dataset function of seaborn. Use Plotly express to plot a
scatter plot for age and fare columns in the titanic dataset.

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import plotly.express as px
fig = px.scatter(titanic, 
                 x="age",
                 y="fare", 
                 title="Titanic Dataset: Age vs. Fare")
fig.update_layout(
    title={
        'text': "Titanic Dataset: Age vs. Fare",
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.show()

# %%
pip install seaborn plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
Q2. Using the tips dataset in the Plotly library, plot a box plot using Plotly express.

# %%
import plotly.express as px
tips_data = px.data.tips()
box_plot = px.box(tips_data, x="day", y="total_bill", title="Box Plot of Total Bill Amount by Day")
box_plot.show()

# %%
Q3. Using the tips dataset in the Plotly library, Plot a histogram for x= "sex" and y="total_bill" column in
the tips dataset. Also, use the "smoker" column with the pattern_shape parameter and the "day"
column with the color parameter

# %%
# Step 1: Import the required libraries
import plotly.express as px

# Step 2: Load the "tips" dataset (it's available in Plotly Express)
tips_data = px.data.tips()

# Step 3: Create a histogram using Plotly Express with pattern_shape and color parameters
histogram = px.histogram(
    tips_data,
    x="sex",
    y="total_bill",
    color="day",
    pattern_shape="smoker",
    title="Histogram of Total Bill by Sex",
)
histogram.show()

# %%
Q4. Using the iris dataset in the Plotly library, Plot a scatter matrix plot, using the "species" column for
the color parameter.
Note: Use "sepal_length", "sepal_width", "petal_length", "petal_width" columns only with the
dimensions parameter.

# %%
import plotly.express as px
iris_data = px.data.iris()
scatter_matrix = px.scatter_matrix(
    iris_data,
    dimensions=["sepal_length", "sepal_width", "petal_length", "petal_width"],
    color="species",
    title="Scatter Matrix Plot of Iris Dataset",
)
scatter_matrix.show()

# %%
Q5. What is Distplot? Using Plotly express, plot a distplot.

# %%
A distplot, short for distribution plot, is a data visualization tool used to display the distribution of a univariate dataset, typically in the form of a histogram and a kernel density estimate (KDE) overlaid on top of it. It allows you to visualize the underlying probability distribution of a continuous variable.

# %%
import plotly.express as px
tips = px.data.tips()
fig = px.histogram(tips, x="total_bill", y="tip", color="sex",
                   marginal="box", # or violin, rug
                   hover_data=tips.columns)
fig.showi
